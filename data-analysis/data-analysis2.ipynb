# %%
import pyspark.pandas as ps

df = ps.read_csv('dbfs:/FileStore/tables/data_analysis/fies_22021.csv', sep=';', index_col = 'ID do estudante')

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Ano do processo seletivo</th>
#       <th>Semestre do processo seletivo</th>
#       <th>Sexo</th>
#       <th>Data de Nascimento</th>
#       <th>UF de resid�ncia</th>
#       <th>Municipio de resid�ncia</th>
#       <th>Etnia/Cor</th>
#       <th>Pessoa com defici�ncia?</th>
#       <th>Tipo de escola no ensino m�dio</th>
#       <th>Ano conclus�o ensino m�dio</th>
#       <th>Concluiu curso superior?</th>
#       <th>Professor rede p�blica ensino?</th>
#       <th>N� de membros Grupo Familiar</th>
#       <th>Renda familiar mensal bruta</th>
#       <th>Renda mensal bruta per capita</th>
#       <th>Regi�o grupo de prefer�ncia</th>
#       <th>UF</th>
#       <th>Cod.Microrregi�o</th>
#       <th>Microrregi�o</th>
#       <th>Cod.Mesorregi�o</th>
#       <th>Mesorregi�o</th>
#       <th>Conceito de curso do GP</th>
#       <th>�rea do conhecimento</th>
#       <th>Sub�rea do conhecimento</th>
#       <th>Cod. do Grupo de prefer�ncia</th>
#       <th>Nota Corte Grupo Prefer�ncia</th>
#       <th>Op��es de cursos da inscri��o</th>
#       <th>Nome mantenedora</th>
#       <th>Natureza Jur�dica Mantenedora</th>
#       <th>CNPJ da mantenedora</th>
#       <th>C�digo e-MEC da Mantenedora</th>
#       <th>Nome da IES</th>
#       <th>C�digo e-MEC da IES</th>
#       <th>Organiza��o Acad�mica da IES</th>
#       <th>Munic�pio da IES</th>
#       <th>UF da IES</th>
#       <th>Nome do Local de oferta</th>
#       <th>C�digo do Local de Oferta</th>
#       <th>Mun�cipio do Local de Oferta</th>
#       <th>UF do Local de Oferta</th>
#       <th>C�digo do curso</th>
#       <th>Nome do curso</th>
#       <th>Turno</th>
#       <th>Grau</th>
#       <th>Conceito</th>
#       <th>M�dia nota Enem</th>
#       <th>Ano do Enem</th>
#       <th>Reda��o</th>
#       <th>Matem�tica e suas Tecnologias</th>
#       <th>Linguagens, C�digos e suas Tec</th>
#       <th>Ci�ncias Natureza e suas Tec</th>
#       <th>Ci�ncias Humanas e suas Tec</th>
#       <th>Situa��o Inscri��o Fies</th>
#       <th>Percentual de financiamento</th>
#       <th>Semestre do financiamento</th>
#       <th>Qtde semestre financiado</th>
#     </tr>
#     <tr>
#       <th>ID do estudante</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>281805657</th>
#       <td>2021</td>
#       <td>2</td>
#       <td>M</td>
#       <td>2000-05-15</td>
#       <td>PR</td>
#       <td>COLOMBO</td>
#       <td>PARDA</td>
#       <td>N�O</td>
#       <td>SIM</td>
#       <td>2017</td>
#       <td>N�O</td>
#       <td>N�O</td>
#       <td>2</td>
#       <td>4253,03</td>
#       <td>1417,68</td>
#       <td>SUL</td>
#       <td>PARAN�</td>
#       <td>41037</td>
#       <td>CURITIBA</td>
#       <td>4110</td>
#       <td>METROPOLITANA DE CURITIBA</td>
#       <td>5</td>
#       <td>CURSOS NAO PRIORITARIOS</td>
#       <td>DIREITO, COM�RCIO EXTERIOR, BIBLIOTECONOMIA E ...</td>
#       <td>41037</td>
#       <td>CURITIBA</td>
#       <td>4110</td>
#       <td>METROPOLITANA DE CURITIBA</td>
#       <td>5</td>
#       <td>CURSOS NAO PRIORITARIOS</td>
#       <td>DIREITO, COM�RCIO EXTERIOR, BIBLIOTECONOMIA E ...</td>
#       <td>125824</td>
#       <td>620,72</td>
#       <td>2</td>
#       <td>ASSOCIACAO PARANAENSE DE CULTURA - APC</td>
#       <td>PESSOA JUR�DICA DE DIREITO PRIVADO - SEM FINS ...</td>
#       <td>76659820000151</td>
#       <td>10</td>
#       <td>PONTIF�CIA UNIVERSIDADE CAT�LICA DO PARAN�</td>
#       <td>10</td>
#       <td>UNIVERSIDADE</td>
#       <td>CURITIBA</td>
#       <td>PR</td>
#       <td>PUCPR - CAMPUS CURITIBA</td>
#       <td>657676</td>
#       <td>CURITIBA</td>
#       <td>PR</td>
#       <td>857</td>
#       <td>DIREITO</td>
#       <td>NOTURNO</td>
#       <td>SEMESTRAL</td>
#       <td>5</td>
#       <td>701,82</td>
#       <td>2011</td>
#       <td>900</td>
#       <td>758,1</td>
#       <td>646,9</td>
#       <td>598,4</td>
#       <td>605,7</td>
#       <td>PARTICIPACAO CANCELADA PELO CANDIDATO</td>
#       <td>None</td>
#       <td></td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>205906170</th>
#       <td>2021</td>
#       <td>2</td>
#       <td>M</td>
#       <td>2089-09-25</td>
#       <td>PR</td>
#       <td>CURITIBA</td>
#       <td>BRANCA</td>
#       <td>N�O</td>
#       <td>SIM</td>
#       <td>2004</td>
#       <td>N�O</td>
#       <td>N�O</td>
#       <td>1</td>
#       <td>1574,07</td>
#       <td>787,04</td>
#       <td>SUL</td>

# %%
df.dropna(inplace=True)
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Ano do processo seletivo</th>
#       <th>Semestre do processo seletivo</th>
#       <th>Sexo</th>
#       <th>Data de Nascimento</th>
#       <th>UF de resid�ncia</th>
#       <th>Municipio de resid�ncia</th>
#       <th>Etnia/Cor</th>
#       <th>Pessoa com defici�ncia?</th>
#       <th>Tipo de escola no ensino m�dio</th>
#       <th>Ano conclus�o ensino m�dio</th>
#       <th>Concluiu curso superior?</th>
#       <th>Professor rede p�blica ensino?</th>
#       <th>N� de membros Grupo Familiar</th>
#       <th>Renda familiar mensal bruta</th>
#       <th>Renda mensal bruta per capita</th>
#       <th>Regi�o grupo de prefer�ncia</th>
#       <th>UF</th>
#       <th>Cod.Microrregi�o</th>
#       <th>Microrregi�o</th>
#       <th>Cod.Mesorregi�o</th>
#       <th>Mesorregi�o</th>
#       <th>Conceito de curso do GP</th>
#       <th>�rea do conhecimento</th>
#       <th>Sub�rea do conhecimento</th>
#       <th>Cod. do Grupo de prefer�ncia</th>
#       <th>Nota Corte Grupo Prefer�ncia</th>
#       <th>Op��es de cursos da inscri��o</th>
#       <th>Nome mantenedora</th>
#       <th>Natureza Jur�dica Mantenedora</th>
#       <th>CNPJ da mantenedora</th>
#       <th>C�digo e-MEC da Mantenedora</th>
#       <th>Nome da IES</th>
#       <th>C�digo e-MEC da IES</th>
#       <th>Organiza��o Acad�mica da IES</th>
#       <td>N�O</td>
#       <td>N�O</td>
#       <td>2020</td>
#       <td>N�O</td>
#       <td>N�O</td>
#       <td>3</td>
#       <td>8678,01</td>
#       <td>2169,5</td>
#       <td>SUL</td>
#       <td>PARAN�</td>
#       <td>4

# %%
df_sex = ps.sql('''
SELECT sexo, count(*) as total
FROM {DF}
GROUP BY sexo
''', DF = df)

# %%
df_sex.plot.bar(x='sexo', y='total')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="3d4fdea4-4d7d-4c51-b1f4-8abce8e18d5d" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3d4fdea4-4d7d-4c51-b1f4-8abce8e18d5d")) {                    Plotly.newPlot(                        "3d4fdea4-4d7d-4c51-b1f4-8abce8e18d5d",                        [{"alignmentgroup":"True","hovertemplate":"sexo=%{x}<br>total=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["F","M"],"xaxis":"x","y":[14675,6199],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker": ...

# %% [markdown]
# ###Fixing Dataset

# %%
# Fixing columns names

df.columns = ['Ano do processo seletivo', 'Semestre do processo seletivo', 'Sexo',
       'Data de Nascimento', 'UF de residência', 'Municipio de residência',
       'Etnia/Cor', 'Pessoa com deficiência?',
       'Tipo de escola no ensino médio', 'Ano conclusão ensino médio',
       'Concluiu curso superior?', 'Professor rede pública ensino?',
       'Nº de membros Grupo Familiar', 'Renda familiar mensal bruta',
       'Renda mensal bruta per capita', 'Região grupo de preferência', 'UF',
       'Cod.Microrregião', 'Microrregião', 'Cod.Mesorregiãoo', 'Mesorregião',
       'Conceito de curso do GP', 'Área do conhecimento',
       'Subárea do conhecimento', 'Cod. do Grupo de preferência',
       'Nota Corte Grupo Preferência', 'Opções de cursos da inscrição',
       'Nome mantenedora', 'Natureza Jurídica Mantenedora',
       'CNPJ da mantenedora', 'Código e-MEC da Mantenedora', 'Nome da IES',
       'Código e-MEC da IES', 'Organização Acadêmica da IES',
       'Município da IES', 'UF da IES', 'Nome do Local de oferta',
       'Código do Local de Oferta', 'Munícipio do Local de Oferta',
       'UF do Local de Oferta', 'Código do curso', 'Nome do curso', 'Turno',
       'Grau', 'Conceito', 'Média nota Enem', 'Ano do Enem', 'Redação',
       'Matemática e suas Tecnologias', 'Linguagens, Códigos e suas Tec',
       'Ciências Natureza e suas Tec', 'Ciências Humanas e suas Tec',
       'Situação Inscrição Fies', 'Percentual de financiamento',
       'Semestre do financiamento', 'Qtde semestre financiado']

# %%
df2 = df[['Redação', 'Matemática e suas Tecnologias', 'Linguagens, Códigos e suas Tec', 'Ciências Natureza e suas Tec', 'Ciências Humanas e suas Tec']]

df2.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Redação</th>
#       <th>Matemática e suas Tecnologias</th>
#       <th>Linguagens, Códigos e suas Tec</th>
#       <th>Ciências Natureza e suas Tec</th>
#       <th>Ciências Humanas e suas Tec</th>
#     </tr>
#     <tr>
#       <th>ID do estudante</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>351412708</th>
#       <td>840</td>
#       <td>744,7</td>
#       <td>644,9</td>
#       <td>685,2</td>
#       <td>726,5</td>
#     </tr>
#     <tr>
#       <th>205956741</th>
#       <td>700</td>
#       <td>599,6</td>
#       <td>546,5</td>
#       <td>469,7</td>
#       <td>493,4</td>
#     </tr>
#     <tr>
#       <th>205958155</th>
#       <td>800</td>
#       <td>672,8</td>
#       <td>425,5</td>
#       <td>606,3</td>
#       <td>703,3</td>
#     </tr>
#     <tr>
#       <th>353015727</th>
#       <td>620</td>
#       <td>639,7</td>
#       <td>566,9</td>
#       <td>604,1</td>
#       <td>667,6</td>
#     </tr>
#     <tr>
#       <th>351073514</th>
#       <td>940</td>
#       <td>818,4</td>
#       <td>640,8</td>
#       <td>676,5</td>
#       <td>666,6</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df2['Redação'] = df2['Redação'].apply(lambda x: x.replace(',', '.')).astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /databricks/python/lib/python3.9/site-packages/pandas/core/apply.py:311, in Apply.transform_str_or_callable(self, func)
#     310 try:
# --> 311     return obj.apply(func, args=args, **kwargs)
#     312 except Exception:
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4330 """
#    4331 Invoke function on values of Series.
#    4332
#    (...)
#    4431 dtype: float64
#    4432 """
# -> 4433 return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/apply.py:1082, in SeriesApply.apply(self)
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/apply.py:1137, in SeriesApply.apply_standard(self)
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#
# File /databricks/python/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# File /databricks/spark/python/pyspark/pandas/series.py:3319, in Series.apply.<locals>.apply_each(s)
#    3318 def apply_each(s: Any) -> pd.Series:
# -> 3319     return s.apply(func, args=args, **kwds)
#
# AttributeError: 'int' object has no attribute 'apply'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File /databricks/python/lib/python3.9/site-packages/pandas/core/apply.py:223, in Apply.transform(self)
#     222 try:
# --> 223     result = self.transform_str_or_callable(func)
#     224 except TypeError:
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/apply.py:313, in Apply.transform_str_or_callable(self, func)
#     312 except Exception:
# --> 313     return func(obj, *args, **kwargs)
#
# File /databricks/spark/python/pyspark/pandas/series.py:3319, in Series.apply.<locals>.apply_each(s)
#    3318 def apply_each(s: Any) -> pd.Series:
# -> 3319     return s.apply(func, args=args, **kwds)
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4330 """
#    4331 Invoke function on values of Series.
#    4332
#    (...)
#    4431 dtype: float64
#    4432 """
# -> 4433 return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/apply.py:1082, in SeriesApply.apply(self)
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/apply.py:1137, in SeriesApply.apply_standard(self)
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#
# File /databricks/python/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# File <command-3799112449425719>:1, in <lambda>(x)
# ----> 1 #df2['Redação'] = df2['Redação'].apply(lambda x: x.replace(',', '.')).astype(float)
#       3 df2['Matemática e suas Tecnologias'] = df2['Matemática e suas Tecnologias'].apply(lambda x: x.replace(',', '.')).astype(float)
#
# AttributeError: 'int' object has no attribute 'replace'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# File <command-3799112449425719>:1
# ----> 1 #df2['Redação'] = df2['Redação'].apply(lambda x: x.replace(',', '.')).astype(float)
#       3 df2['Matemática e suas Tecnologias'] = df2['Matemática e suas Tecnologias'].apply(lambda x: x.replace(',', '.')).astype(float)
#       5 df2['Linguagens, Códigos e suas Tec'] = df2['Linguagens, Códigos e suas Tec'].apply(lambda x: x.replace(',', '.')).astype(float)
#
# File /databricks/spark/python/pyspark/instrumentation_utils.py:48, in _wrap_function.<locals>.wrapper(*args, **kwargs)
#      46 start = time.perf_counter()
#      47 try:
# ---> 48     res = func(*args, **kwargs)
#      49     logger.log_success(
#      50         module_name, class_name, function_name, time.perf_counter() - start, signature
#      51     )
#      52     return res
#
# File /databricks/spark/python/pyspark/pandas/series.py:3322, in Series.apply(self, func, args, **kwds)
#    3319     return s.apply(func, args=args, **kwds)
#    3321 if should_infer_schema:
# -> 3322     return self.pandas_on_spark._transform_batch(apply_each, None)
#    3323 else:
#    3324     sig_return = infer_return_type(func)
#
# File /databricks/spark/python/pyspark/pandas/accessors.py:920, in PandasOnSparkSeriesMethods._transform_batch(self, func, return_type)
#     918 limit = ps.get_option("compute.shortcut_limit")
#     919 pser = self._psser.head(limit + 1)._to_internal_pandas()
# --> 920 transformed = pser.transform(func)
#     921 psser: Series = Series(transformed)
#     923 field = psser._internal.data_fields[0].normalize_spark_type()
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/series.py:4318, in Series.transform(self, func, axis, *args, **kwargs)
#    4308 @doc(
#    4309     _shared_docs["transform"],
#    4310     klass=_shared_doc_kwargs["klass"],
#    (...)
#    4315 ) -> DataFrame | Series:
#    4316     # Validate axis argument
#    4317     self._get_axis_number(axis)
# -> 4318     result = SeriesApply(
#    4319         self, func=func, convert_dtype=True, args=args, kwargs=kwargs
#    4320     ).transform()
#    4321     return result
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/apply.py:227, in Apply.transform(self)
#     225     raise
#     226 except Exception as err:
# --> 227     raise ValueError("Transform function failed") from err
#     229 # Functions that transform may return empty Series/DataFrame
#     230 # when the dtype is not appropriate
#     231 if (
#     232     isinstance(result, (ABCSeries, ABCDataFrame))
#     233     and result.empty
#     234     and not obj.empty
#     235 ):
#
# ValueError: Transform function failed

# %%
df2['Matemática e suas Tecnologias'] = df2['Matemática e suas Tecnologias'].apply(lambda x: x.replace(',', '.')).astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /databricks/python/lib/python3.9/site-packages/pandas/core/apply.py:311, in Apply.transform_str_or_callable(self, func)
#     310 try:
# --> 311     return obj.apply(func, args=args, **kwargs)
#     312 except Exception:
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4330 """
#    4331 Invoke function on values of Series.
#    4332
#    (...)
#    4431 dtype: float64
#    4432 """
# -> 4433 return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/apply.py:1082, in SeriesApply.apply(self)
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/apply.py:1137, in SeriesApply.apply_standard(self)
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#
# File /databricks/python/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# File /databricks/spark/python/pyspark/pandas/series.py:3319, in Series.apply.<locals>.apply_each(s)
#    3318 def apply_each(s: Any) -> pd.Series:
# -> 3319     return s.apply(func, args=args, **kwds)
#
# AttributeError: 'float' object has no attribute 'apply'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File /databricks/python/lib/python3.9/site-packages/pandas/core/apply.py:223, in Apply.transform(self)
#     222 try:
# --> 223     result = self.transform_str_or_callable(func)
#     224 except TypeError:
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/apply.py:313, in Apply.transform_str_or_callable(self, func)
#     312 except Exception:
# --> 313     return func(obj, *args, **kwargs)
#
# File /databricks/spark/python/pyspark/pandas/series.py:3319, in Series.apply.<locals>.apply_each(s)
#    3318 def apply_each(s: Any) -> pd.Series:
# -> 3319     return s.apply(func, args=args, **kwds)
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4330 """
#    4331 Invoke function on values of Series.
#    4332
#    (...)
#    4431 dtype: float64
#    4432 """
# -> 4433 return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/apply.py:1082, in SeriesApply.apply(self)
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/apply.py:1137, in SeriesApply.apply_standard(self)
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#
# File /databricks/python/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# File <command-3799112449425721>:1, in <lambda>(x)
# ----> 1 df2['Matemática e suas Tecnologias'] = df2['Matemática e suas Tecnologias'].apply(lambda x: x.replace(',', '.')).astype(float)
#
# AttributeError: 'float' object has no attribute 'replace'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# File <command-3799112449425721>:1
# ----> 1 df2['Matemática e suas Tecnologias'] = df2['Matemática e suas Tecnologias'].apply(lambda x: x.replace(',', '.')).astype(float)
#
# File /databricks/spark/python/pyspark/instrumentation_utils.py:48, in _wrap_function.<locals>.wrapper(*args, **kwargs)
#      46 start = time.perf_counter()
#      47 try:
# ---> 48     res = func(*args, **kwargs)
#      49     logger.log_success(
#      50         module_name, class_name, function_name, time.perf_counter() - start, signature
#      51     )
#      52     return res
#
# File /databricks/spark/python/pyspark/pandas/series.py:3322, in Series.apply(self, func, args, **kwds)
#    3319     return s.apply(func, args=args, **kwds)
#    3321 if should_infer_schema:
# -> 3322     return self.pandas_on_spark._transform_batch(apply_each, None)
#    3323 else:
#    3324     sig_return = infer_return_type(func)
#
# File /databricks/spark/python/pyspark/pandas/accessors.py:920, in PandasOnSparkSeriesMethods._transform_batch(self, func, return_type)
#     918 limit = ps.get_option("compute.shortcut_limit")
#     919 pser = self._psser.head(limit + 1)._to_internal_pandas()
# --> 920 transformed = pser.transform(func)
#     921 psser: Series = Series(transformed)
#     923 field = psser._internal.data_fields[0].normalize_spark_type()
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/series.py:4318, in Series.transform(self, func, axis, *args, **kwargs)
#    4308 @doc(
#    4309     _shared_docs["transform"],
#    4310     klass=_shared_doc_kwargs["klass"],
#    (...)
#    4315 ) -> DataFrame | Series:
#    4316     # Validate axis argument
#    4317     self._get_axis_number(axis)
# -> 4318     result = SeriesApply(
#    4319         self, func=func, convert_dtype=True, args=args, kwargs=kwargs
#    4320     ).transform()
#    4321     return result
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/apply.py:227, in Apply.transform(self)
#     225     raise
#     226 except Exception as err:
# --> 227     raise ValueError("Transform function failed") from err
#     229 # Functions that transform may return empty Series/DataFrame
#     230 # when the dtype is not appropriate
#     231 if (
#     232     isinstance(result, (ABCSeries, ABCDataFrame))
#     233     and result.empty
#     234     and not obj.empty
#     235 ):
#
# ValueError: Transform function failed

# %%
df2['Linguagens, Códigos e suas Tec'] = df2['Linguagens, Códigos e suas Tec'].apply(lambda x: x.replace(',', '.')).astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /databricks/python/lib/python3.9/site-packages/pandas/core/apply.py:311, in Apply.transform_str_or_callable(self, func)
#     310 try:
# --> 311     return obj.apply(func, args=args, **kwargs)
#     312 except Exception:
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4330 """
#    4331 Invoke function on values of Series.
#    4332
#    (...)
#    4431 dtype: float64
#    4432 """
# -> 4433 return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/apply.py:1082, in SeriesApply.apply(self)
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/apply.py:1137, in SeriesApply.apply_standard(self)
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#
# File /databricks/python/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# File /databricks/spark/python/pyspark/pandas/series.py:3319, in Series.apply.<locals>.apply_each(s)
#    3318 def apply_each(s: Any) -> pd.Series:
# -> 3319     return s.apply(func, args=args, **kwds)
#
# AttributeError: 'float' object has no attribute 'apply'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File /databricks/python/lib/python3.9/site-packages/pandas/core/apply.py:223, in Apply.transform(self)
#     222 try:
# --> 223     result = self.transform_str_or_callable(func)
#     224 except TypeError:
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/apply.py:313, in Apply.transform_str_or_callable(self, func)
#     312 except Exception:
# --> 313     return func(obj, *args, **kwargs)
#
# File /databricks/spark/python/pyspark/pandas/series.py:3319, in Series.apply.<locals>.apply_each(s)
#    3318 def apply_each(s: Any) -> pd.Series:
# -> 3319     return s.apply(func, args=args, **kwds)
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4330 """
#    4331 Invoke function on values of Series.
#    4332
#    (...)
#    4431 dtype: float64
#    4432 """
# -> 4433 return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/apply.py:1082, in SeriesApply.apply(self)
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/apply.py:1137, in SeriesApply.apply_standard(self)
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#
# File /databricks/python/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# File <command-3799112449425725>:1, in <lambda>(x)
# ----> 1 df2['Linguagens, Códigos e suas Tec'] = df2['Linguagens, Códigos e suas Tec'].apply(lambda x: x.replace(',', '.')).astype(float)
#
# AttributeError: 'float' object has no attribute 'replace'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# File <command-3799112449425725>:1
# ----> 1 df2['Linguagens, Códigos e suas Tec'] = df2['Linguagens, Códigos e suas Tec'].apply(lambda x: x.replace(',', '.')).astype(float)
#
# File /databricks/spark/python/pyspark/instrumentation_utils.py:48, in _wrap_function.<locals>.wrapper(*args, **kwargs)
#      46 start = time.perf_counter()
#      47 try:
# ---> 48     res = func(*args, **kwargs)
#      49     logger.log_success(
#      50         module_name, class_name, function_name, time.perf_counter() - start, signature
#      51     )
#      52     return res
#
# File /databricks/spark/python/pyspark/pandas/series.py:3322, in Series.apply(self, func, args, **kwds)
#    3319     return s.apply(func, args=args, **kwds)
#    3321 if should_infer_schema:
# -> 3322     return self.pandas_on_spark._transform_batch(apply_each, None)
#    3323 else:
#    3324     sig_return = infer_return_type(func)
#
# File /databricks/spark/python/pyspark/pandas/accessors.py:920, in PandasOnSparkSeriesMethods._transform_batch(self, func, return_type)
#     918 limit = ps.get_option("compute.shortcut_limit")
#     919 pser = self._psser.head(limit + 1)._to_internal_pandas()
# --> 920 transformed = pser.transform(func)
#     921 psser: Series = Series(transformed)
#     923 field = psser._internal.data_fields[0].normalize_spark_type()
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/series.py:4318, in Series.transform(self, func, axis, *args, **kwargs)
#    4308 @doc(
#    4309     _shared_docs["transform"],
#    4310     klass=_shared_doc_kwargs["klass"],
#    (...)
#    4315 ) -> DataFrame | Series:
#    4316     # Validate axis argument
#    4317     self._get_axis_number(axis)
# -> 4318     result = SeriesApply(
#    4319         self, func=func, convert_dtype=True, args=args, kwargs=kwargs
#    4320     ).transform()
#    4321     return result
#
# File /databricks/python/lib/python3.9/site-packages/pandas/core/apply.py:227, in Apply.transform(self)
#     225     raise
#     226 except Exception as err:
# --> 227     raise ValueError("Transform function failed") from err
#     229 # Functions that transform may return empty Series/DataFrame
#     230 # when the dtype is not appropriate
#     231 if (
#     232     isinstance(result, (ABCSeries, ABCDataFrame))
#     233     and result.empty
#     234     and not obj.empty
#     235 ):
#
# ValueError: Transform function failed

# %%
df2['Ciências Natureza e suas Tec'] = df2['Ciências Natureza e suas Tec'].apply(lambda x: x.replace(',', '.')).astype(float)

# %%
df2['Ciências Humanas e suas Tec'] = df2['Ciências Humanas e suas Tec'].apply(lambda x: x.replace(',', '.')).astype(float)

# %%
df2.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Redação</th>
#       <th>Matemática e suas Tecnologias</th>
#       <th>Linguagens, Códigos e suas Tec</th>
#       <th>Ciências Natureza e suas Tec</th>
#       <th>Ciências Humanas e suas Tec</th>
#     </tr>
#     <tr>
#       <th>ID do estudante</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>351412708</th>
#       <td>840</td>
#       <td>744.7</td>
#       <td>644.9</td>
#       <td>685.2</td>
#       <td>726.5</td>
#     </tr>
#     <tr>
#       <th>205956741</th>
#       <td>700</td>
#       <td>599.6</td>
#       <td>546.5</td>
#       <td>469.7</td>
#       <td>493.4</td>
#     </tr>
#     <tr>
#       <th>205958155</th>
#       <td>800</td>
#       <td>672.8</td>
#       <td>425.5</td>
#       <td>606.3</td>
#       <td>703.3</td>
#     </tr>
#     <tr>
#       <th>353015727</th>
#       <td>620</td>
#       <td>639.7</td>
#       <td>566.9</td>
#       <td>604.1</td>
#       <td>667.6</td>
#     </tr>
#     <tr>
#       <th>351073514</th>
#       <td>940</td>
#       <td>818.4</td>
#       <td>640.8</td>
#       <td>676.5</td>
#       <td>666.6</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Correlation

# %%
df2.corr().style.background_gradient(cmap='Purples', vmin=-1, vmax=1)
# Out:
# /databricks/spark/python/pyspark/sql/pandas/conversion.py:122: UserWarning:
#
# toPandas attempted Arrow optimization because 'spark.sql.execution.arrow.pyspark.enabled' is set to true; however, failed by the reason below:
#   Unable to convert the field pearson(__correlation_output__). If this column is not necessary, you may consider dropping it or converting to primitive type before the conversion.
# Direct cause: Unsupported type in conversion to Arrow: MatrixUDT()
# Attempting non-optimization as 'spark.sql.execution.arrow.pyspark.fallback.enabled' is set to true.
# <style type="text/css">
# #T_78994_row0_col0, #T_78994_row1_col1, #T_78994_row2_col2, #T_78994_row3_col3, #T_78994_row4_col4 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_78994_row0_col1, #T_78994_row1_col0 {
#   background-color: #7970b3;
#   color: #f1f1f1;
# }
# #T_78994_row0_col2, #T_78994_row2_col0 {
#   background-color: #796eb2;
#   color: #f1f1f1;
# }
# #T_78994_row0_col3, #T_78994_row3_col0 {
#   background-color: #7a71b4;
#   color: #f1f1f1;
# }
# #T_78994_row0_col4, #T_78994_row4_col0 {
#   background-color: #7f7bb9;
#   color: #f1f1f1;
# }
# #T_78994_row1_col2, #T_78994_row2_col1 {
#   background-color: #6b53a4;
#   color: #f1f1f1;
# }
# #T_78994_row1_col3, #T_78994_row3_col1, #T_78994_row3_col4, #T_78994_row4_col3 {
#   background-color: #64459e;
#   color: #f1f1f1;
# }
# #T_78994_row1_col4, #T_78994_row4_col1 {
#   background-color: #6950a3;
#   color: #f1f1f1;
# }
# #T_78994_row2_col3, #T_78994_row3_col2 {
#   background-color: #694fa2;
#   color: #f1f1f1;
# }
# #T_78994_row2_col4, #T_78994_row4_col2 {
#   background-color: #62429c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_78994">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78994_level0_col0" class="col_heading level0 col0" >Redação</th>
#       <th id="T_78994_level0_col1" class="col_heading level0 col1" >Matemática e suas Tecnologias</th>
#       <th id="T_78994_level0_col2" class="col_heading level0 col2" >Linguagens, Códigos e suas Tec</th>
#       <th id="T_78994_level0_col3" class="col_heading level0 col3" >Ciências Natureza e suas Tec</th>
#       <th id="T_78994_level0_col4" class="col_heading level0 col4" >Ciências Humanas e suas Tec</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78994_level0_row0" class="row_heading level0 row0" >Redação</th>
#       <td id="T_78994_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_78994_row0_col1" class="data row0 col1" >0.322136</td>
#       <td id="T_78994_row0_col2" class="data row0 col2" >0.329476</td>
#       <td id="T_78994_row0_col3" class="data row0 col3" >0.316261</td>
#       <td id="T_78994_row0_col4" class="data row0 col4" >0.258916</td>
#     </tr>
#     <tr>
#       <th id="T_78994_level0_row1" class="row_heading level0 row1" >Matemática e suas Tecnologias</th>
#       <td id="T_78994_row1_col0" class="data row1 col0" >0.322136</td>
#       <td id="T_78994_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_78994_row1_col2" class="data row1 col2" >0.489192</td>
#       <td id="T_78994_row1_col3" class="data row1 col3" >0.570014</td>
#       <td id="T_78994_row1_col4" class="data row1 col4" >0.504442</td>
#     </tr>
#     <tr>
#       <th id="T_78994_level0_row2" class="row_heading level0 row2" >Linguagens, Códigos e suas Tec</th>
#       <td id="T_78994_row2_col0" class="data row2 col0" >0.329476</td>
#       <td id="T_78994_row2_col1" class="data row2 col1" >0.489192</td>
#       <td id="T_78994_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_78994_row2_col3" class="data row2 col3" >0.514951</td>
#       <td id="T_78994_row2_col4" class="data row2 col4" >0.587629</td>
#     </tr>
#     <tr>
#       <th id="T_78994_level0_row3" class="row_heading level0 row3" >Ciências Natureza e suas Tec</th>
#       <td id="T_78994_row3_col0" class="data row3 col0" >0.316261</td>
#       <td id="T_78994_row3_col1" class="data row3 col1" >0.570014</td>
#       <td id="T_78994_row3_col2" class="data row3 col2" >0.514951</td>
#       <td id="T_78994_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_78994_row3_col4" class="data row3 col4" >0.563208</td>
#     </tr>
#     <tr>
#       <th id="T_78994_level0_row4" class="row_heading level0 row4" >Ciências Humanas e suas Tec</th>
#       <td id="T_78994_row4_col0" class="data row4 col0" >0.258916</td>
#       <td id="T_78994_row4_col1" class="data row4 col1" >0.504442</td>
#       <td id="T_78994_row4_col2" class="data row4 col2" >0.587629</td>
#       <td id="T_78994_row4_col3" class="data row4 col3" >0.563208</td>
#       <td id="T_78994_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
