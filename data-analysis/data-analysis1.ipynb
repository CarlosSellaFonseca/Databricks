# %%
dbutils.fs.mkdirs('/FileStore/tables/data_analysis/')
# Out:
# Out[82]: True

# %%
file_local = '/FileStore/tables/data_analysis/cursos_prouni.csv'

# %%
import pyspark.pandas as ps

df = ps.read_csv(file_local, index_col='curso_id')

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>grau</th>
#       <th>turno</th>
#       <th>mensalidade</th>
#       <th>bolsa_integral_cotas</th>
#       <th>bolsa_integral_ampla</th>
#       <th>bolsa_parcial_cotas</th>
#       <th>bolsa_parcial_ampla</th>
#       <th>curso_busca</th>
#       <th>cidade_busca</th>
#       <th>uf_busca</th>
#       <th>cidade_filtro</th>
#       <th>universidade_nome</th>
#       <th>campus_nome</th>
#       <th>campus_id</th>
#       <th>nome</th>
#       <th>nota_integral_ampla</th>
#       <th>nota_integral_cotas</th>
#       <th>nota_parcial_ampla</th>
#       <th>nota_parcial_cotas</th>
#     </tr>
#     <tr>
# ...

# %%
df.shape
# Out:
# Out[86]: (41447, 19)

# %%
df['curso_busca'].equals(df['nome']).sum()
# Out:
# Out[87]: 41447

# %%
df = df.drop(['curso_busca'], axis=1)

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>grau</th>
#       <th>turno</th>
#       <th>mensalidade</th>
#       <th>bolsa_integral_cotas</th>
#       <th>bolsa_integral_ampla</th>
#       <th>bolsa_parcial_cotas</th>
#       <th>bolsa_parcial_ampla</th>
#       <th>cidade_busca</th>
#       <th>uf_busca</th>
#       <th>cidade_filtro</th>
#       <th>universidade_nome</th>
#       <th>campus_nome</th>
#       <th>campus_id</th>
#       <th>nome</th>
#       <th>nota_integral_ampla</th>
#       <th>nota_integral_cotas</th>
#       <th>nota_parcial_ampla</th>
#       <th>nota_parcial_cotas</th>
#     </tr>
#     <tr>
#       <th>curso_id</th>
# ...

# %%
df = df.rename(columns={'nome':'nome_curso'})

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>grau</th>
#       <th>turno</th>
#       <th>mensalidade</th>
#       <th>bolsa_integral_cotas</th>
#       <th>bolsa_integral_ampla</th>
#       <th>bolsa_parcial_cotas</th>
#       <th>bolsa_parcial_ampla</th>
#       <th>cidade_busca</th>
#       <th>uf_busca</th>
#       <th>cidade_filtro</th>
#       <th>universidade_nome</th>
#       <th>campus_nome</th>
#       <th>campus_id</th>
#       <th>nome_curso</th>
#       <th>nota_integral_ampla</th>
#       <th>nota_integral_cotas</th>
#       <th>nota_parcial_ampla</th>
#       <th>nota_parcial_cotas</th>
#     </tr>
#     <tr>
#       <th>curso_id</th>
# ...

# %%
df[df['nome_curso']=='Medicina']['nome_curso'].count()
# Out:
# Out[92]: 124

# %%
df['turno'].unique()
# Out:
# Out[93]: 0             Matutino
# 1    Curso a Distância
# 2           Vespertino
# 3             Integral
# 4              Noturno
# Name: turno, dtype: object

# %%
df[(df['turno']=='Integral') & (df['nome_curso']=='Medicina')]['nome_curso'].count()
# Out:
# Out[94]: 123

# %%
df[(df['turno']=='Integral') & (df['nome_curso']=='Medicina') | (df['turno']=='Matutino') & (df['nome_curso']=='Medicina')]['nome_curso'].count()
# Out:
# Out[95]: 124

# %%
file_local = '/FileStore/tables/data_analysis/reajuste.csv'
df_fee = ps.read_csv(file_local)

# %%
df_fee.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>reajuste</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>100</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df_fee.shape
# Out:
# Out[98]: (41447, 1)

# %%
ps.set_option('compute.ops_on_diff_frames', True)

# %%
df.reset_index(inplace=True)

# %%
df['mensalidade'] = df['mensalidade']+df_fee['reajuste']

# %%
df.dropna(inplace=True)
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>curso_id</th>
#       <th>grau</th>
#       <th>turno</th>
#       <th>mensalidade</th>
#       <th>bolsa_integral_cotas</th>
#       <th>bolsa_integral_ampla</th>
#       <th>bolsa_parcial_cotas</th>
#       <th>bolsa_parcial_ampla</th>
#       <th>cidade_busca</th>
#       <th>uf_busca</th>
#       <th>cidade_filtro</th>
#       <th>universidade_nome</th>
#       <th>campus_nome</th>
#       <th>campus_id</th>
#       <th>nome_curso</th>
#       <th>nota_integral_ampla</th>
#       <th>nota_integral_cotas</th>
#       <th>nota_parcial_ampla</th>
#       <th>nota_parcial_cotas</th>
#     </tr>
#   </thead>
# ...

# %%
df.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>curso_id</th>
#       <th>mensalidade</th>
#       <th>bolsa_integral_cotas</th>
#       <th>bolsa_integral_ampla</th>
#       <th>bolsa_parcial_cotas</th>
#       <th>bolsa_parcial_ampla</th>
#       <th>campus_id</th>
#       <th>nota_integral_ampla</th>
#       <th>nota_integral_cotas</th>
#       <th>nota_parcial_ampla</th>
#       <th>nota_parcial_cotas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>2.203000e+03</td>
#       <td>2203.000000</td>
#       <td>2203.000000</td>
#       <td>2203.000000</td>
#       <td>2203.000000</td>
#       <td>2203.000000</td>
# ...

# %%
df_description = df[df['nome_curso']=='Medicina'].describe()

# %%
df_description = df_description.drop(['mensalidade', 'curso_id', 'campus_id', 'nota_integral_ampla', 'nota_integral_cotas', 'nota_parcial_ampla', 'nota_parcial_cotas'], axis=1)

# %%
df_description
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>bolsa_integral_cotas</th>
#       <th>bolsa_integral_ampla</th>
#       <th>bolsa_parcial_cotas</th>
#       <th>bolsa_parcial_ampla</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>15.000000</td>
#       <td>15.000000</td>
#       <td>15.000000</td>
#       <td>15.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>2.800000</td>
#       <td>2.266667</td>
#       <td>4.466667</td>
#       <td>3.866667</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>1.859339</td>
#       <td>1.533747</td>
#       <td>2.587516</td>
#       <td>2.669047</td>
# ...

# %%
df_description = df_description.drop(['count'], axis = 0)

# %%
df_description.style.format('{:,.2f}').background_gradient(axis=1)
# Out:
# <style type="text/css">
# #T_168c8_row0_col0 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_168c8_row0_col1, #T_168c8_row1_col1, #T_168c8_row2_col0, #T_168c8_row2_col1, #T_168c8_row2_col2, #T_168c8_row2_col3, #T_168c8_row3_col0, #T_168c8_row3_col1, #T_168c8_row3_col2, #T_168c8_row4_col1, #T_168c8_row5_col1, #T_168c8_row6_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_168c8_row0_col2, #T_168c8_row1_col3, #T_168c8_row3_col3, #T_168c8_row4_col2, #T_168c8_row5_col2, #T_168c8_row6_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_168c8_row0_col3 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_168c8_row1_col0 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_168c8_row1_col2 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_168c8_row4_col0 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_168c8_row4_col3 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_168c8_row5_col0 {
# ...

# %%
df_medicine = df.query("nome_curso=='Medicina'")
df_medicine.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>curso_id</th>
#       <th>grau</th>
#       <th>turno</th>
#       <th>mensalidade</th>
#       <th>bolsa_integral_cotas</th>
#       <th>bolsa_integral_ampla</th>
#       <th>bolsa_parcial_cotas</th>
#       <th>bolsa_parcial_ampla</th>
#       <th>cidade_busca</th>
#       <th>uf_busca</th>
#       <th>cidade_filtro</th>
#       <th>universidade_nome</th>
#       <th>campus_nome</th>
#       <th>campus_id</th>
#       <th>nome_curso</th>
#       <th>nota_integral_ampla</th>
#       <th>nota_integral_cotas</th>
#       <th>nota_parcial_ampla</th>
#       <th>nota_parcial_cotas</th>
#     </tr>
#   </thead>
# ...

# %%
df_medicine['mensalidade'].mean()
# Out:
# Out[110]: 8007.354666666666

# %%
df_medicine.query("turno == 'Integral' AND cidade_busca == 'Sao Paulo'")
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>curso_id</th>
#       <th>grau</th>
#       <th>turno</th>
#       <th>mensalidade</th>
#       <th>bolsa_integral_cotas</th>
#       <th>bolsa_integral_ampla</th>
#       <th>bolsa_parcial_cotas</th>
#       <th>bolsa_parcial_ampla</th>
#       <th>cidade_busca</th>
#       <th>uf_busca</th>
#       <th>cidade_filtro</th>
#       <th>universidade_nome</th>
#       <th>campus_nome</th>
#       <th>campus_id</th>
#       <th>nome_curso</th>
#       <th>nota_integral_ampla</th>
#       <th>nota_integral_cotas</th>
#       <th>nota_parcial_ampla</th>
#       <th>nota_parcial_cotas</th>
#     </tr>
#   </thead>
# ...

# %%
grouped = df_medicine.query("turno == 'Integral' OR turno == 'Matutino'").groupby('uf_busca')['mensalidade'].mean()

# %%
grouped
# Out:
# Out[113]: uf_busca
# RO    7009.970000
# SP    8477.466667
# ES    6113.000000
# PB    7512.700000
# MG    7712.500000
# PA    8608.540000
# RJ    9123.070000
# MA    8381.375000
# AC    9774.340000
# PR    7174.275000
# Name: mensalidade, dtype: float64

# %%
df_grouped = ps.DataFrame(grouped)

# %%
df_grouped
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>mensalidade</th>
#     </tr>
#     <tr>
#       <th>uf_busca</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>RO</th>
#       <td>7009.970000</td>
#     </tr>
#     <tr>
#       <th>SP</th>
#       <td>8477.466667</td>
#     </tr>
#     <tr>
#       <th>ES</th>
#       <td>6113.000000</td>
#     </tr>
#     <tr>
#       <th>PB</th>
#       <td>7512.700000</td>
#     </tr>
#     <tr>
#       <th>MG</th>
#       <td>7712.500000</td>
#     </tr>
#     <tr>
#       <th>PA</th>
#       <td>8608.540000</td>
#     </tr>
#     <tr>
#       <th>RJ</th>
#       <td>9123.070000</td>
# ...

# %%
df_grouped.sort_values(by='mensalidade', inplace=True, ascending=False)

# %%
df_grouped
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>mensalidade</th>
#     </tr>
#     <tr>
#       <th>uf_busca</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AC</th>
#       <td>9774.340000</td>
#     </tr>
#     <tr>
#       <th>RJ</th>
#       <td>9123.070000</td>
#     </tr>
#     <tr>
#       <th>PA</th>
#       <td>8608.540000</td>
#     </tr>
#     <tr>
#       <th>SP</th>
#       <td>8477.466667</td>
#     </tr>
#     <tr>
#       <th>MA</th>
#       <td>8381.375000</td>
#     </tr>
#     <tr>
#       <th>MG</th>
#       <td>7712.500000</td>
#     </tr>
#     <tr>
#       <th>PB</th>
#       <td>7512.700000</td>
# ...

# %%
df_grouped = df_grouped.reset_index()

# %%
df_grouped.plot.bar(x='uf_busca', y='mensalidade')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ps.sql('''
SELECT bolsa_integral_cotas, uf_busca
FROM {DF}
WHERE nome_curso = 'Medicina'
LIMIT 5
''', DF = df)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>bolsa_integral_cotas</th>
#       <th>uf_busca</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2</td>
#       <td>SP</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>SP</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4</td>
#       <td>RO</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>PR</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>RJ</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
quotas = ps.sql('''
SELECT uf_busca, SUM(bolsa_integral_cotas) AS quotas_total
FROM {DF}
WHERE nome_curso = 'Medicina'
GROUP BY uf_busca
ORDER BY quotas_total DESC
''', DF = df)

# %%
quotas.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>uf_busca</th>
#       <th>quotas_total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>PB</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>MA</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>SP</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>RO</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>RJ</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
quotas.plot.bar(x='uf_busca', y='quotas_total')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_medicine['cidade_busca'].unique()
# Out:
# Out[124]: 0          Sao Luis
# 1       Joao Pessoa
# 2             Belem
# 3         Itaperuna
# 4           Vitoria
# 5            Franca
# 6         Sao Paulo
# 7        Guarapuava
# 8      Campo Mourao
# 9     Montes Claros
# 10       Rio Branco
# 11       Imperatriz
# 12       Vespasiano
# 13      Porto Velho
# Name: cidade_busca, dtype: object

# %%
cities = {
    "Sao Luis": "Capital",
    "Joao Pessoa": "Município",
    "Belem": "Capital",
    "Itaperuna": "Município",
    "Vitoria": "Município",
    "Franca": "Município",
    "Sao Paulo": "Capital",
    "Guarapuava": "Município",
    "Campo Mourao": "Município",
    "Montes Claros": "Município",
    "Rio Branco": "Município",
    "Imperatriz": "Município",
    "Vespasiano": "Município",
    "Porto Velho": "Município"
}

# %%
capitals = df_medicine['cidade_busca'].map(cities)

# %%
df_medicine.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>curso_id</th>
#       <th>grau</th>
#       <th>turno</th>
#       <th>mensalidade</th>
#       <th>bolsa_integral_cotas</th>
#       <th>bolsa_integral_ampla</th>
#       <th>bolsa_parcial_cotas</th>
#       <th>bolsa_parcial_ampla</th>
#       <th>cidade_busca</th>
#       <th>uf_busca</th>
#       <th>cidade_filtro</th>
#       <th>universidade_nome</th>
#       <th>campus_nome</th>
#       <th>campus_id</th>
#       <th>nome_curso</th>
#       <th>nota_integral_ampla</th>
#       <th>nota_integral_cotas</th>
#       <th>nota_parcial_ampla</th>
#       <th>nota_parcial_cotas</th>
#     </tr>
#   </thead>
# ...

# %%
df_medicine.insert(loc=9, column='tipo_cidade', value=capitals)

# %%
df_medicine.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>curso_id</th>
#       <th>grau</th>
#       <th>turno</th>
#       <th>mensalidade</th>
#       <th>bolsa_integral_cotas</th>
#       <th>bolsa_integral_ampla</th>
#       <th>bolsa_parcial_cotas</th>
#       <th>bolsa_parcial_ampla</th>
#       <th>cidade_busca</th>
#       <th>tipo_cidade</th>
#       <th>uf_busca</th>
#       <th>cidade_filtro</th>
#       <th>universidade_nome</th>
#       <th>campus_nome</th>
#       <th>campus_id</th>
#       <th>nome_curso</th>
#       <th>nota_integral_ampla</th>
#       <th>nota_integral_cotas</th>
#       <th>nota_parcial_ampla</th>
#       <th>nota_parcial_cotas</th>
# ...

# %%
quotas2 = ps.sql('''
SELECT tipo_cidade, SUM(bolsa_integral_cotas) as quotas_total
FROM {DF}
GROUP BY tipo_cidade
ORDER BY 2 DESC
''', DF = df_medicine)

quotas2.plot.bar(x='tipo_cidade', y='quotas_total')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###Correlation

# %%
aux = df_medicine[['mensalidade', 'bolsa_integral_cotas', 'bolsa_integral_ampla', 'bolsa_parcial_cotas', 'bolsa_parcial_ampla', 'nota_integral_ampla', 'nota_integral_cotas', 'nota_parcial_ampla', 'nota_parcial_cotas']]

# %%
aux.corr().style.background_gradient(cmap='Reds', vmin=-1, vmax=1)
# Out:
# /databricks/spark/python/pyspark/sql/pandas/conversion.py:122: UserWarning:
#
# toPandas attempted Arrow optimization because 'spark.sql.execution.arrow.pyspark.enabled' is set to true; however, failed by the reason below:
#   Unable to convert the field pearson(__correlation_output__). If this column is not necessary, you may consider dropping it or converting to primitive type before the conversion.
# Direct cause: Unsupported type in conversion to Arrow: MatrixUDT()
# Attempting non-optimization as 'spark.sql.execution.arrow.pyspark.fallback.enabled' is set to true.
# <style type="text/css">
# #T_9a969_row0_col0, #T_9a969_row1_col1, #T_9a969_row2_col2, #T_9a969_row3_col3, #T_9a969_row4_col4, #T_9a969_row5_col5, #T_9a969_row6_col6, #T_9a969_row7_col7, #T_9a969_row8_col8 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_9a969_row0_col1, #T_9a969_row0_col2, #T_9a969_row1_col0, #T_9a969_row2_col0, #T_9a969_row2_col8, #T_9a969_row8_col2 {
#   background-color: #f75b40;
# ...

# %%
df_medicine.plot.scatter(x='mensalidade', y='bolsa_parcial_cotas', trendline='ols', trendline_color_override = 'red')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#R2 = 0.214219
# For a good line regression, R2 should be near 1

# %%
df_medicine.plot.scatter(x='nota_parcial_ampla', y='nota_parcial_cotas', trendline='ols', trendline_color_override = 'red')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#R2 = 0.494172
# 'nota_parcial_ampla' and 'nota_parcial_cotas' have a higher relationship represented by the line

# %% [markdown]
# ###Boxplots

# %%
##EXAMPLE

import pyspark.pandas as ps

data = {'Produto': ['A', 'B', 'C', 'A', 'B', 'C', 'A', 'B', 'C', 'A', 'B', 'C'],
        'Preço (R$)': [1200, 1500, 1000, 1300, 1600, 1100, 1250, 1550, 1050, 1350, 1450, 1150]}

df_teste = ps.DataFrame(data)

df_teste.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Produto</th>
#       <th>Preço (R$)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>A</td>
#       <td>1200</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>B</td>
#       <td>1500</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>C</td>
#       <td>1000</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>A</td>
#       <td>1300</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>B</td>
#       <td>1600</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#EXAMPLE

df_teste['Preço (R$)'].plot.box()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df[df['turno']=='Integral']['mensalidade'].plot.box()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df[df['turno']=='Matutino']['mensalidade'].plot.box()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df[df['nome_curso']=='Medicina']['mensalidade'].plot.box()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df[df['nome_curso']=='Enfermagem']['mensalidade'].plot.box()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###String methods

# %%
df_medicine['universidade_nome'].unique()
# Out:
# Out[143]: 0             Faculdades Integradas Pitágoras - FIP-MOC
# 1          Faculdade da Saúde e Ecologia Humana - FASEH
# 2                          Faculdade das Américas - FAM
# 3           Faculdade Metropolitana da Amazônia - FAMAZ
# 4     Faculdade de Ciências Médicas da Paraíba - FCM-PB
# 5                      Faculdade Redentor - FACREDENTOR
# 6                   Faculdade Barão do Rio Branco - FAB
# 7             Universidade Cidade de São Paulo - UNICID
# 8        Centro Universitário Integrado de Campo Mourão
# 9                     Faculdade Campo Real - CAMPO REAL
# 10               Centro Universitário São Lucas - UniSL
# 11              Faculdade Brasileira - MULTIVIX VITÓRIA
# 12          Universidade do Ceuma - Uniceuma - UNICEUMA
# 13                     Universidade de Franca - UNIFRAN
# Name: universidade_nome, dtype: object

# %%
selection = df_medicine[df_medicine['universidade_nome'].str.contains('Universidade')][['universidade_nome']]

# %%
selection
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>universidade_nome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>Universidade Cidade de São Paulo - UNICID</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Universidade do Ceuma - Uniceuma - UNICEUMA</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Universidade do Ceuma - Uniceuma - UNICEUMA</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>Universidade de Franca - UNIFRAN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df_medicine['universidade_nome'].loc[42] = 'Centro Universitario Integrado de Campo Mourão - CUICM'
df_medicine['universidade_nome'].loc[42]
# Out:
# Out[146]: 'Centro Universitario Integrado de Campo Mourão - CUICM'

# %%
df_med_sep = df_medicine['universidade_nome'].str.split(' - ', n=1, expand=True)
df_med_sep
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>22</th>
#       <td>Faculdade das Américas</td>
#       <td>FAM</td>
#     </tr>
#     <tr>
#       <th>71</th>
#       <td>Universidade de Franca</td>
#       <td>UNIFRAN</td>
#     </tr>
#     <tr>
#       <th>87</th>
#       <td>Centro Universitário São Lucas</td>
#       <td>UniSL</td>
#     </tr>
#     <tr>
#       <th>107</th>
#       <td>Faculdade Campo Real</td>
#       <td>CAMPO REAL</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Faculdade Redentor</td>
#       <td>FACREDENTOR</td>
#     </tr>
#     <tr>
# ...

# %%
df_medicine.insert(loc=12, column='sigla', value=df_med_sep[1])

# %%
df_medicine.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>curso_id</th>
#       <th>grau</th>
#       <th>turno</th>
#       <th>mensalidade</th>
#       <th>bolsa_integral_cotas</th>
#       <th>bolsa_integral_ampla</th>
#       <th>bolsa_parcial_cotas</th>
#       <th>bolsa_parcial_ampla</th>
#       <th>cidade_busca</th>
#       <th>tipo_cidade</th>
#       <th>uf_busca</th>
#       <th>cidade_filtro</th>
#       <th>sigla</th>
#       <th>universidade_nome</th>
#       <th>campus_nome</th>
#       <th>campus_id</th>
#       <th>nome_curso</th>
#       <th>nota_integral_ampla</th>
#       <th>nota_integral_cotas</th>
#       <th>nota_parcial_ampla</th>
# ...

# %%
grades = ps.sql('''
SELECT sigla, MEAN(nota_integral_ampla) AS grade_mean
FROM {DF}
GROUP BY sigla
ORDER BY grade_mean DESC
''', DF = df_medicine)

grades.plot.bar(x='sigla', y='grade_mean')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# https://pt.wikipedia.org/wiki/Programa_Universidade_para_Todos

# %%
import pandas as pd

data = {
    'Ano': [2021, 2020],
    'Bolsas_Integrais': [145.3, 182.9],
    'Bolsas_Parciais': [150.0, 237.4],
    'Bolsas_Total': [286.3, 420.3]
}

# %%
df_pandas = pd.DataFrame(data)

# %%
import pyspark.pandas as ps

df = ps.from_pandas(df_pandas)
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Ano</th>
#       <th>Bolsas_Integrais</th>
#       <th>Bolsas_Parciais</th>
#       <th>Bolsas_Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2021</td>
#       <td>145.3</td>
#       <td>150.0</td>
#       <td>286.3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2020</td>
#       <td>182.9</td>
#       <td>237.4</td>
#       <td>420.3</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.plot.bar(x='Ano', y=['Bolsas_Integrais', 'Bolsas_Parciais'], barmode='group')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
url = 'https://pt.wikipedia.org/wiki/Ensino_superior_no_Brasil'

# %%
# !pip install lxml
# Out:
# ...
#   Using cached lxml-4.9.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (7.1 MB)
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-3a92d543-d9be-4a68-a929-3fcc6b53b3cc/bin/python -m pip install --upgrade pip' command.

# %%
list_html = ps.read_html(url)

# %%
len(list_html)
# Out:
# Out[158]: 5

# %%
df_publics = lista[0]
df_publics
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-3799112449425762>:1
# ----> 1 df_publics = lista[0]
#       2 df_publics
#
# NameError: name 'lista' is not defined

# %%
type(df_publics)

# %%
df_publics.sort_values(by=['Classificação Nacional'], inplace=True, ascending=False)

# %%
fig = df_publics.plot.bar(x='sigla', y='Classificação Nacional', color=range(10))
fig.layout.coloraxis.showscale = False
fig.show()

# %% [markdown]
# ### Saving data to Parquet Files with partition

# %%
file_local = '/FileStore/tables/data_analysis/cursos_prouni.csv'

# %%
df_publics.to_parquet('/FileStore/tables/publics_parquet', partition_cols='Classificação Nacional')

# %% [markdown]
# ### Reading Parquet Files

# %%
ps.read_parquet('/FileStore/tables/publics_parquet')
